# %%
print("""\
# *************************************************************************** #
# *************************************************************************** #
# TP7 : APPLICATIONS CHOISIES DES BASES DE GROEBNER                           #
# *************************************************************************** #
# *************************************************************************** #
""")

# CONSIGNES
#
# Les seules lignes a modifier sont annoncee par "Code pour l'exercice"
# indique en commmentaire et son signalees
# Ne changez pas le nom des variables
#
# CONSEILS
#
# Ce modele vous sert a restituer votre travail. Il est deconseille d'ecrire
# une longue suite d'instruction et de debugger ensuite. Il vaut mieux tester
# le code que vous produisez ligne apres ligne, afficher les resultats et
# controler que les objets que vous definissez sont bien ceux que vous attendez.
#
# Vous devez verifier votre code en le testant, y compris par des exemples que
# vous aurez fabrique vous-meme.
#


reset()
print("""\
# ****************************************************************************
# POINTS SINGULIERS 
# ****************************************************************************
""")


# Donnees de l'enonce de l'exercice

MPol.<x,y> = PolynomialRing(QQ,2)
f = 5*x^4 - 10*x^3 + 10*x^2*y^2 - 40*x^2*y + 40*x^2 - 10*x*y^2 + 40*x*y - 32*x + 5*y^4 - 40*y^3 + 115*y^2 - 136*y + 48

# Code pour l'EXERCICE

PtsSinguliers = [(1,1)] # A calculer


# # Affichage des resultats

print "La liste des points d'inflexions est :",PtsSinguliers
G1 = implicit_plot(f,(x,-2,6),(y,-2,6),color='blue')
G2 = points(PtsSinguliers,color='red')
show(G1+G2)

reset()
print("""\
# ****************************************************************************
#  VALUATIONS
# ****************************************************************************
""")


# Donnees de l'enonce de l'exercice

A.<x,y,z> = AffineSpace(QQ, 3)
QQ5.<rac5> = QuadraticField(5)
f1 = x^2+y^2-1
f2 = 5*x-(z-3)^2
Z = Curve([f1,f2],A)
n = z^2-6*z+5
d = x^2-x+y^2

# Code pour l'EXERCICE

var('theta')
x(theta) = theta
y(theta) = theta^2
z(theta) = theta^3

reponse2=""

zeros = []
poles = []

# # Affichage des resultats

parametric_plot3d((x,y,z),(theta,0,2))  

print reponse2
print "Confirmation de la lissité de la courbe : ", Z.is_smooth()

print "L'ensemble des zeros munis de leur multiplicité de h est",zeros
print "L'ensemble des poles munis de leur multiplicité de h est",poles



reset()
print("""\
# ****************************************************************************
#  ENVELOPPE
# ****************************************************************************
""")


# Donnees de l'enonce de l'exercice

MPol.<x,y,t> = PolynomialRing(QQ,3) # ORDRE DES VARIABLES A FIXER
f = (x-t)^2+(y+t^2-4*t)^2-4

# Code pour l'EXERCICE

reponse1 = "La courbe (Ct) est un XXX(A COMPLETER) dont le XXX décrit un XXX quand t varie"

eq_enveloppe = x+y
f(x,y) = eq_enveloppe

reponse4 = "Oui/Non"

# # Affichage des resultats

print reponse1

print "L'enveloppe de la famille de courbe a pour equation",eq_enveloppe
implicit_plot(f,(x,-5,5),(y,-5,5)) 

print "La bille expulsée tape-t-elle le toit ?", reponse4

reset()
print("""\
# ****************************************************************************
#  COLORATION DE GRAPHES
# ****************************************************************************
""")


# Donnees de l'enonce de l'exercice

G= Graph(12)
G.add_cycle(range(8))
G.add_edges([(i,i+4) for i in range(4) ])
G.add_edges([(8,5),(8,7),(9,0),(9,2),(10,1), (10,3),(11,4),(11,6) ])
G.add_edges([(8,9),(9,10),(10,11)])
G.show()
G.coloring()

MPol = PolynomialRing(QQ,12,'x',
order = 'invlex')
phi (v) = v^3-1
psi (u,v) = u^2+u*v+v^2
IG= Ideal(MPol, [phi(MPol.gen(v)) for v in G.vertices()] + [psi(MPol.gen(u),MPol.gen(v)) for (u,v) in G.edges(labels=false)])

# Code pour l'EXERCICE

reponse1 = 0
base = []
reponse3 = "vos explications pour la question 3"

# # Affichage des resultats

print "Il faut",reponse1,"couleurs pour colorer ce graphe"
print "Une base de Groebner de I(G,3) est", base
print reponse3

reset()
print("""\
# ****************************************************************************
#  PREUVE DE THEOREMES GEOMETRIQUES
# ****************************************************************************
""")


# Donnees de l'enonce de l'exercice

MPol.<x,y,u,v> = PolynomialRing(QQ,4)


# Code pour l'EXERCICE

IA = Ideal(MPol,[1])
IB = Ideal(MPol,[1])
IC = Ideal(MPol,[1])

reponse2  = "votre reponse pour la question 2"

reponse4 = "votre reponse pour la question 4"

# # Affichage des resultats

print "Les idéaux IA, IB et IC sont", IA, IB, IC
print reponse2
print "detailler votre raisonnement pour la question 3"
print reponse4



reset()
print("""\
# ****************************************************************************
#  PROGRAMMATION ENTIERE
# ****************************************************************************
""")


# Donnees de l'enonce de l'exercice

MPol.<p,n,d,q> = PolynomialRing(QQ,4)
I=Ideal([p^5-n,p^10-d,p^25-q])

# Code pour l'EXERCICE

base = []
reponse2 = "vos explications"

# # Affichage des resultats

print "Base de Groebner",base
print (p^117).reduce(I)
print reponse2

reset()
print("""\
# ****************************************************************************
#  SURFACE DE CLEBSCH
# ****************************************************************************
""")


# Donnees de l'enonce de l'exercice

MPol.<x1,x2,x3> = PolynomialRing(QQ,3)
f=x1^3+x2^3+x3^3+1-(x1+x2+x3+1)^3

# Code pour l'EXERCICE


# # Affichage des resultats

implicit_plot3d(f,(x1,-5,5),(x2,-5,5),(x3,-5,5))

# %% [markdown]
# ### Question 267

# %%
reset()
print("""\
# ****************************************************************************
# POINTS SINGULIERS 
# ****************************************************************************
""")


# Donnees de l'enonce de l'exercice

MPol.<x,y> = PolynomialRing(QQ,2)
f = 5*x^4 - 10*x^3 + 10*x^2*y^2 - 40*x^2*y + 40*x^2 - 10*x*y^2 + 40*x*y - 32*x + 5*y^4 - 40*y^3 + 115*y^2 - 136*y + 48
dfdx = diff(f,x)
dfdy = diff(f,y)
# Code pour l'EXERCICE
G = Ideal([f,dfdx,dfdy]).groebner_basis()

# la premier equation a eliminé la variable x

racines_y = G[0].univariate_polynomial().roots(multiplicities=False) 

# une racine de multiplicité 2

racines_x = G[1].subs(y=racines_y[0]).univariate_polynomial().roots(multiplicities=False)

PtsSinguliers = [(racines_x[0],racines_y[0])] # A calculer


# # Affichage des resultats

print "La liste des points d'inflexions est :",PtsSinguliers
G1 = implicit_plot(f,(x,-2,6),(y,-2,6),color='blue')
G2 = points(PtsSinguliers,color='red')
show(G1+G2)
# Out:
# # ****************************************************************************
# # POINTS SINGULIERS
# # ****************************************************************************
#
# La liste des points d'inflexions est : [(4/5, 12/5)]
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ### Question 277

# %%
reset()
print("""\
# ****************************************************************************
#  VALUATIONS
# ****************************************************************************
""")


# Donnees de l'enonce de l'exercice

A.<x,y,z> = AffineSpace(QQ, 3)
QQ5.<rac5> = QuadraticField(5)
f1 = x^2+y^2-1
f2 = 5*x-(z-3)^2
Z = Curve([f1,f2],A)
n = z^2-6*z+5
d = x^2-x+y^2

# Code pour l'EXERCICE

var('theta')
x(theta) = sin(theta)
y(theta) = cos(theta)
z(theta) = 3 + sqrt(5*sin(theta))

# pour verifier que Z est lisse il faut recoudre f1=0 f2=0 et 
# nabla(f1)^nabla(f2) = 0 et verifier l'ensemble des solutions


V =  vector(f1.gradient()).cross_product(vector(f2.gradient()))
vx = V[0]
vy = V[1]

G = Ideal([f1,f2,vx,vy]).groebner_basis()

# sisteme d'equations linearies

ry = G[0].univariate_polynomial().roots(multiplicities = False)
rx = G[1].univariate_polynomial().roots(multiplicities = False)
rz = G[2].univariate_polynomial().roots(multiplicities = False)

# solutions

PtsSinguliers = [(rx[0],ry[0],rz[0]),(rx[0],ry[1],rz[0])]

Ps = points(PtsSinguliers,color='red')

reponse2="On peut verifier que les candidats à points singuliers sont dans une region où la courbe n'est pas definie"

zeros = []
poles = []

# # Affichage des resultats

Z1 = parametric_plot3d((x,y,z),(theta,0,pi()))  


show(Z1+Ps)
print reponse2
print "Confirmation de la lissité de la courbe : ", Z.is_smooth()

print "L'ensemble des zeros munis de leur multiplicité de h est",zeros
print "L'ensemble des poles munis de leur multiplicité de h est",poles
# Out:
# # ****************************************************************************
# #  VALUATIONS
# # ****************************************************************************
# Graphics3d Object
# On peut verifier que les candidats à points singuliers sont dans une region où la courbe n'est pas definie
# Confirmation de la lissité de la courbe :  True
# L'ensemble des zeros munis de leur multiplicité de h est []
# L'ensemble des poles munis de leur multiplicité de h est []

# %% [markdown]
# ### Question 287

# %%
reset()
print("""\
# ****************************************************************************
#  ENVELOPPE
# ****************************************************************************
""")


# Donnees de l'enonce de l'exercice

MPol.<x,y,t> = PolynomialRing(QQ,3,order = 'invlex') 
f = (x-t)^2+(y+t^2-4*t)^2-4

# Code pour l'EXERCICE


reponse1 = "La courbe (Ct) est un cercle de rayon 2 dont le centre décrit une parabole quand t varie"

# calcule de la derive partiel en t

dfdt = diff(f,t)

# calcul de la base de groebner

G = Ideal([f,dfdt]).groebner_basis()

# avec l'ordre invlex, on trouve une equation qui elimine t

eq_enveloppe = G[len(G)-1]

feq(x,y) = eq_enveloppe

# 3.

T = [QQ(0.5*t) for t in range (-20,20,1)]

reponse4 = "Oui/Non"

# # Affichage des resultats

print reponse1

print "L'enveloppe de la famille de courbe a pour equation",eq_enveloppe
S = implicit_plot(feq,(x,-20,20),(y,-20,20)) 
PolPlot.<x,y> = PolynomialRing(QQ,2) 
for i in range(len(T)):
    ff = PolPlot(f.subs(t = T[i]))
    S = S + implicit_plot(ff,(x,-20,20),(y,-20,20)) 

show(S)
reset()    
print "\n4. La trajectoire du centre de masse des billes est une parabole, decrit presque par les memes equations.\nIl faut changer l'equation du y avec g ~ 9.8:\ncela done y + 4t - 98/20t^2"

MPol.<x,y,t> = PolynomialRing(QQ,3,order = 'invlex') 
f = (x-t)^2+(y+t^2-98/20*t)^2-4
dfdt = diff(f,t)
G = Ideal([f,dfdt]).groebner_basis()
eq_enveloppe = G[len(G)-1]
feq(x,y) = eq_enveloppe
T = [QQ(0.5*t) for t in range (20)]
S = implicit_plot(feq,(x,-20,20),(y,-20,20)) 
PolPlot.<x,y> = PolynomialRing(QQ,2) 
for i in range(len(T)):
    ff = PolPlot(f.subs(t = T[i]))
    S = S + implicit_plot(ff,(x,-20,20),(y,-20,20)) 
show(S)

reponse4 = 'Oui!'

print "La bille expulsée tape-t-elle le toit ?", reponse4
# Out:
# # ****************************************************************************
# #  ENVELOPPE
# # ****************************************************************************
#
# La courbe (Ct) est un cercle de rayon 2 dont le centre décrit une parabole quand t varie
# L'enveloppe de la famille de courbe a pour equation y^4 + 2*x^2*y^3 - 8*x*y^3 + 1/2*y^3 + x^4*y^2 - 8*x^3*y^2 - 6*x^2*y^2 + 88*x*y^2 - 1535/16*y^2 - 11/2*x^4*y + 44*x^3*y + 81/8*x^2*y - 785/2*x*y + 486*y + x^6 - 12*x^5 + 865/16*x^4 - 225/2*x^3 - 76*x^2 + 692*x - 2897/4
# Graphics object consisting of 41 graphics primitives
# 4. La trajectoire du centre de masse des billes est une parabole, decrit presque par les memes equations.
# Il faut changer l'equation du y avec g ~ 9.8:
# cela done y + 4t - 98/20t^2
# Graphics object consisting of 21 graphics primitives
# La bille expulsée tape-t-elle le toit ? Oui!

# %%
98/20
# Out:
# 49/10

# %%
G[2]
# Out:
